# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.array([42, 46, 42, 71, 80, 74, 70]).reshape((-1,1))
y=np.array([130, 115, 148, 100, 156, 162, 151])

plt.plot(x,y)
